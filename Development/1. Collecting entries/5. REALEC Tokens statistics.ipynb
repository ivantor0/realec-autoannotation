# %% [markdown]
# Let's import the libraries we will need in this display

# %%
from IPython.display import display, clear_output
import shutil
import numpy as np
import pandas as pd

# %% [markdown]
# Now we fetch our tokens data

# %%
from google.colab import drive
drive.mount('/content/gdrive', force_remount=True)
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3Aietf%3Awg%3Aoauth%3A2.0%3Aoob&scope=email%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdocs.test%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fdrive.photos.readonly%20https%3A%2F%2Fwww.googleapis.com%2Fauth%2Fpeopleapi.readonly&response_type=code
#
# Enter your authorization code:
# ··········
# Mounted at /content/gdrive

# %%
filename = "All_Entries.json"
shutil.copy2('/content/gdrive/My Drive/'+filename,'.')

All_Entries = pd.read_json(filename).reset_index(drop=True)
All_Entries.begin = All_Entries.begin.astype(int)
All_Entries.end = All_Entries.end.astype(int)
All_Entries.delete = All_Entries.delete.astype(bool)
All_Entries.substr_words = All_Entries.substr_words.astype(int)

# %% [markdown]
# Now let's plot!

# %%
# %matplotlib inline

import matplotlib.pyplot as plt

# %% [markdown]
# ## Bar plot

# %%
#@title Choose an error type to display bar plot { run: "auto", form-width: "35%" }

error = "Choice of lexical item" #@param ["Generic correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Choice of tense", "Tense form", "Voice", "Modals", "Verb pattern", "Intransitive verb", "Transitive verb", "Reflexive verb", "Verb with as", "Ambitransitive verb", "Two verbal forms in the predicate", "Verb + Infinitive", "Verb + Gerund", "Verb + Infinitive OR Gerund", "Verb + Bare Infinitive", "Verb + Object/Addressee + Bare Infinitive", "Infinitive Restoration Alternation", "Verb + Participle", "Get + participle", "Complex-object verb", "Verbal idiom", "Prepositional or phrasal verb", "Dative verb with alternation", "Verb followed by a clause", "Verb + that/WH + Clause", "Verb + if/whether + clause", "Verb + that + Subjunctive clause", "Verb + it + Conj + Clause", "Participial construction", "Infinitive construction", "Gerund phrase", "Nouns", "Countable/uncountable", "Prepositional noun", "Possessive form of a noun", "Noun as an attribute", "Noun + Infinitive", "Noun number", "Prepositions", "Conjunctions", "Adjectives", "Comparative degree of adjectives", "Superlative degree of adjectives", "Prepositional adjective", "Adjective as a collective noun", "Adverbs", "Comparative degree of adverbs", "Superlative degree of adverbs", "Prepositional adverb", "Numerals", "Pronouns", "Agreement", "Word order", "Standard word order", "Emphatic shift", "Cleft sentence", "Interrogative word order", "Incomplete sentence", "Exclamation", "Title structure", "Note structure", "Conditionals", "Attributes", "Relative clause", "Defining relative clause", "Non-defining relative clause", "Coordinate relative clause", "Attributive participial construction", "Parallel constructions", "Negation", "Comparative construction", "Numerical comparison", "Confusion of structures", "Vocabulary", "Word choice", "Choice of lexical item", "Words often confused", "Choice of a part of lexical item", "Absence of certain components of a collocation", "Redundant word(s)", "Word formation", "Derivational affixes", "Formational suffix", "Formational prefix", "Confusion of categories", "Compound word", "Discourse", "Referential device", "Coherence", "Linking device", "Inappropriate register", "Absence of a component in clause or sentence", "Redundant component in clause or sentence", "Absence of necessary explanation or detail", "Deletion"]

Conventional = ["Generic correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Choice of tense", "Tense form", "Voice", "Modals", "Verb pattern", "Intransitive verb", "Transitive verb", "Reflexive verb", "Verb with as", "Ambitransitive verb", "Two verbal forms in the predicate", "Verb + Infinitive", "Verb + Gerund", "Verb + Infinitive OR Gerund", "Verb + Bare Infinitive", "Verb + Object/Addressee + Bare Infinitive", "Infinitive Restoration Alternation", "Verb + Participle", "Get + participle", "Complex-object verb", "Verbal idiom", "Prepositional or phrasal verb", "Dative verb with alternation", "Verb followed by a clause", "Verb + that/WH + Clause", "Verb + if/whether + clause", "Verb + that + Subjunctive clause", "Verb + it + Conj + Clause", "Participial construction", "Infinitive construction", "Gerund phrase", "Nouns", "Countable/uncountable", "Prepositional noun", "Possessive form of a noun", "Noun as an attribute", "Noun + Infinitive", "Noun number", "Prepositions", "Conjunctions", "Adjectives", "Comparative degree of adjectives", "Superlative degree of adjectives", "Prepositional adjective", "Adjective as a collective noun", "Adverbs", "Comparative degree of adverbs", "Superlative degree of adverbs", "Prepositional adverb", "Numerals", "Pronouns", "Agreement", "Word order", "Standard word order", "Emphatic shift", "Cleft sentence", "Interrogative word order", "Incomplete sentence", "Exclamation", "Title structure", "Note structure", "Conditionals", "Attributes", "Relative clause", "Defining relative clause", "Non-defining relative clause", "Coordinate relative clause", "Attributive participial construction", "Parallel constructions", "Negation", "Comparative construction", "Numerical comparison", "Confusion of structures", "Vocabulary", "Word choice", "Choice of lexical item", "Words often confused", "Choice of a part of lexical item", "Absence of certain components of a collocation", "Redundant word(s)", "Word formation", "Derivational affixes", "Formational suffix", "Formational prefix", "Confusion of categories", "Compound word", "Discourse", "Referential device", "Coherence", "Linking device", "Inappropriate register", "Absence of a component in clause or sentence", "Redundant component in clause or sentence", "Absence of necessary explanation or detail", "Deletion"]
Tags = ["Correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Tense_choice", "Tense_form", "Voice", "Modals", "Verb_pattern", "Intransitive", "Transitive", "Reflexive_verb", "Presentation", "Ambitransitive", "Two_in_a_row", "Verb_Inf", "Verb_Gerund", "Verb_Inf_Gerund", "Verb_Bare_Inf", "Verb_object_bare", "Restoration_alter", "Verb_part", "Get_part", "Complex_obj", "Verbal_idiom", "Prepositional_verb", "Dative", "Followed_by_a_clause", "that_clause", "if_whether_clause", "that_subj_clause", "it_conj_clause", "Participial_constr", "Infinitive_constr", "Gerund_phrase", "Nouns", "Countable_uncountable", "Prepositional_noun", "Possessive", "Noun_attribute", "Noun_inf", "Noun_number", "Prepositions", "Conjunctions", "Adjectives", "Comparative_adj", "Superlative_adj", "Prepositional_adjective", "Adj_as_collective", "Adverbs", "Comparative_adv", "Superlative_adv", "Prepositional_adv", "Numerals", "Pronouns", "Agreement_errors", "Word_order", "Standard", "Emphatic", "Cleft", "Interrogative", "Abs_comp_clause", "Exclamation", "Title_structure", "Note_structure", "Conditionals", "Attributes", "Relative_clause", "Defining", "Non_defining", "Coordinate", "Attr_participial", "Lack_par_constr", "Negation", "Comparative_constr", "Numerical", "Confusion_of_structures", "Vocabulary", "Word_choice", "lex_item_choice", "Often_confused", "lex_part_choice", "Absence_comp_colloc", "Redundant", "Derivation", "Formational_affixes", "Suffix", "Prefix", "Category_confusion", "Compound_word", "Discourse", "Ref_device", "Coherence", "Linking_device", "Inappropriate_register", "Absence_comp_sent", "Redundant_comp", "Absence_explanation", "delete"]
translate_dict = {e[0]: e[1] for e in zip(Conventional, Tags)}

error = translate_dict[error]

if error == "delete":
  data = All_Entries.loc[All_Entries['delete'] == True]
else:
  data = All_Entries.loc[All_Entries['type'] == error]
data = data.groupby('substr_words').size()
ax = data.plot(kind='bar')
ax.set_xlabel('Number of words')
ax.set_ylabel('Number of tokens')
plt.figure(figsize=(18, 5))


print('Total number of', error, 'tokens:', str(sum(data)))
# Out:
# Total number of lex_item_choice tokens: 11114

# %% [markdown]
# ## Pie plot

# %%
#@title Choose an error type to display pie plot { run: "auto", form-width: "35%" }

error = "Choice of lexical item" #@param ["Generic correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Choice of tense", "Tense form", "Voice", "Modals", "Verb pattern", "Intransitive verb", "Transitive verb", "Reflexive verb", "Verb with as", "Ambitransitive verb", "Two verbal forms in the predicate", "Verb + Infinitive", "Verb + Gerund", "Verb + Infinitive OR Gerund", "Verb + Bare Infinitive", "Verb + Object/Addressee + Bare Infinitive", "Infinitive Restoration Alternation", "Verb + Participle", "Get + participle", "Complex-object verb", "Verbal idiom", "Prepositional or phrasal verb", "Dative verb with alternation", "Verb followed by a clause", "Verb + that/WH + Clause", "Verb + if/whether + clause", "Verb + that + Subjunctive clause", "Verb + it + Conj + Clause", "Participial construction", "Infinitive construction", "Gerund phrase", "Nouns", "Countable/uncountable", "Prepositional noun", "Possessive form of a noun", "Noun as an attribute", "Noun + Infinitive", "Noun number", "Prepositions", "Conjunctions", "Adjectives", "Comparative degree of adjectives", "Superlative degree of adjectives", "Prepositional adjective", "Adjective as a collective noun", "Adverbs", "Comparative degree of adverbs", "Superlative degree of adverbs", "Prepositional adverb", "Numerals", "Pronouns", "Agreement", "Word order", "Standard word order", "Emphatic shift", "Cleft sentence", "Interrogative word order", "Incomplete sentence", "Exclamation", "Title structure", "Note structure", "Conditionals", "Attributes", "Relative clause", "Defining relative clause", "Non-defining relative clause", "Coordinate relative clause", "Attributive participial construction", "Parallel constructions", "Negation", "Comparative construction", "Numerical comparison", "Confusion of structures", "Vocabulary", "Word choice", "Choice of lexical item", "Words often confused", "Choice of a part of lexical item", "Absence of certain components of a collocation", "Redundant word(s)", "Word formation", "Derivational affixes", "Formational suffix", "Formational prefix", "Confusion of categories", "Compound word", "Discourse", "Referential device", "Coherence", "Linking device", "Inappropriate register", "Absence of a component in clause or sentence", "Redundant component in clause or sentence", "Absence of necessary explanation or detail", "Deletion"]

Conventional = ["Generic correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Choice of tense", "Tense form", "Voice", "Modals", "Verb pattern", "Intransitive verb", "Transitive verb", "Reflexive verb", "Verb with as", "Ambitransitive verb", "Two verbal forms in the predicate", "Verb + Infinitive", "Verb + Gerund", "Verb + Infinitive OR Gerund", "Verb + Bare Infinitive", "Verb + Object/Addressee + Bare Infinitive", "Infinitive Restoration Alternation", "Verb + Participle", "Get + participle", "Complex-object verb", "Verbal idiom", "Prepositional or phrasal verb", "Dative verb with alternation", "Verb followed by a clause", "Verb + that/WH + Clause", "Verb + if/whether + clause", "Verb + that + Subjunctive clause", "Verb + it + Conj + Clause", "Participial construction", "Infinitive construction", "Gerund phrase", "Nouns", "Countable/uncountable", "Prepositional noun", "Possessive form of a noun", "Noun as an attribute", "Noun + Infinitive", "Noun number", "Prepositions", "Conjunctions", "Adjectives", "Comparative degree of adjectives", "Superlative degree of adjectives", "Prepositional adjective", "Adjective as a collective noun", "Adverbs", "Comparative degree of adverbs", "Superlative degree of adverbs", "Prepositional adverb", "Numerals", "Pronouns", "Agreement", "Word order", "Standard word order", "Emphatic shift", "Cleft sentence", "Interrogative word order", "Incomplete sentence", "Exclamation", "Title structure", "Note structure", "Conditionals", "Attributes", "Relative clause", "Defining relative clause", "Non-defining relative clause", "Coordinate relative clause", "Attributive participial construction", "Parallel constructions", "Negation", "Comparative construction", "Numerical comparison", "Confusion of structures", "Vocabulary", "Word choice", "Choice of lexical item", "Words often confused", "Choice of a part of lexical item", "Absence of certain components of a collocation", "Redundant word(s)", "Word formation", "Derivational affixes", "Formational suffix", "Formational prefix", "Confusion of categories", "Compound word", "Discourse", "Referential device", "Coherence", "Linking device", "Inappropriate register", "Absence of a component in clause or sentence", "Redundant component in clause or sentence", "Absence of necessary explanation or detail", "Deletion"]
Tags = ["Correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Tense_choice", "Tense_form", "Voice", "Modals", "Verb_pattern", "Intransitive", "Transitive", "Reflexive_verb", "Presentation", "Ambitransitive", "Two_in_a_row", "Verb_Inf", "Verb_Gerund", "Verb_Inf_Gerund", "Verb_Bare_Inf", "Verb_object_bare", "Restoration_alter", "Verb_part", "Get_part", "Complex_obj", "Verbal_idiom", "Prepositional_verb", "Dative", "Followed_by_a_clause", "that_clause", "if_whether_clause", "that_subj_clause", "it_conj_clause", "Participial_constr", "Infinitive_constr", "Gerund_phrase", "Nouns", "Countable_uncountable", "Prepositional_noun", "Possessive", "Noun_attribute", "Noun_inf", "Noun_number", "Prepositions", "Conjunctions", "Adjectives", "Comparative_adj", "Superlative_adj", "Prepositional_adjective", "Adj_as_collective", "Adverbs", "Comparative_adv", "Superlative_adv", "Prepositional_adv", "Numerals", "Pronouns", "Agreement_errors", "Word_order", "Standard", "Emphatic", "Cleft", "Interrogative", "Abs_comp_clause", "Exclamation", "Title_structure", "Note_structure", "Conditionals", "Attributes", "Relative_clause", "Defining", "Non_defining", "Coordinate", "Attr_participial", "Lack_par_constr", "Negation", "Comparative_constr", "Numerical", "Confusion_of_structures", "Vocabulary", "Word_choice", "lex_item_choice", "Often_confused", "lex_part_choice", "Absence_comp_colloc", "Redundant", "Derivation", "Formational_affixes", "Suffix", "Prefix", "Category_confusion", "Compound_word", "Discourse", "Ref_device", "Coherence", "Linking_device", "Inappropriate_register", "Absence_comp_sent", "Redundant_comp", "Absence_explanation", "delete"]
translate_dict = {e[0]: e[1] for e in zip(Conventional, Tags)}

error = translate_dict[error]

if error == "delete":
  data = All_Entries.loc[All_Entries['delete'] == True]
else:
  data = All_Entries.loc[All_Entries['type'] == error]
data = data.groupby('substr_words').size()
ax = data.plot(kind='pie')
plt.figure(figsize=(18, 5))


print('Total number of', error, 'tokens:', str(sum(data)))
# Out:
# Total number of lex_item_choice tokens: 11114

# %% [markdown]
# ## General summary

# %%
Conventional = ["Generic correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Choice of tense", "Tense form", "Voice", "Modals", "Verb pattern", "Intransitive verb", "Transitive verb", "Reflexive verb", "Verb with as", "Ambitransitive verb", "Two verbal forms in the predicate", "Verb + Infinitive", "Verb + Gerund", "Verb + Infinitive OR Gerund", "Verb + Bare Infinitive", "Verb + Object/Addressee + Bare Infinitive", "Infinitive Restoration Alternation", "Verb + Participle", "Get + participle", "Complex-object verb", "Verbal idiom", "Prepositional or phrasal verb", "Dative verb with alternation", "Verb followed by a clause", "Verb + that/WH + Clause", "Verb + if/whether + clause", "Verb + that + Subjunctive clause", "Verb + it + Conj + Clause", "Participial construction", "Infinitive construction", "Gerund phrase", "Nouns", "Countable/uncountable", "Prepositional noun", "Possessive form of a noun", "Noun as an attribute", "Noun + Infinitive", "Noun number", "Prepositions", "Conjunctions", "Adjectives", "Comparative degree of adjectives", "Superlative degree of adjectives", "Prepositional adjective", "Adjective as a collective noun", "Adverbs", "Comparative degree of adverbs", "Superlative degree of adverbs", "Prepositional adverb", "Numerals", "Pronouns", "Agreement", "Word order", "Standard word order", "Emphatic shift", "Cleft sentence", "Interrogative word order", "Incomplete sentence", "Exclamation", "Title structure", "Note structure", "Conditionals", "Attributes", "Relative clause", "Defining relative clause", "Non-defining relative clause", "Coordinate relative clause", "Attributive participial construction", "Parallel constructions", "Negation", "Comparative construction", "Numerical comparison", "Confusion of structures", "Vocabulary", "Word choice", "Choice of lexical item", "Words often confused", "Choice of a part of lexical item", "Absence of certain components of a collocation", "Redundant word(s)", "Word formation", "Derivational affixes", "Formational suffix", "Formational prefix", "Confusion of categories", "Compound word", "Discourse", "Referential device", "Coherence", "Linking device", "Inappropriate register", "Absence of a component in clause or sentence", "Redundant component in clause or sentence", "Absence of necessary explanation or detail", "Deletion"]
Tags = ["Correction", "Punctuation", "Spelling", "Capitalisation", "Grammar", "Determiners", "Articles", "Quantifiers", "Verbs", "Tense", "Tense_choice", "Tense_form", "Voice", "Modals", "Verb_pattern", "Intransitive", "Transitive", "Reflexive_verb", "Presentation", "Ambitransitive", "Two_in_a_row", "Verb_Inf", "Verb_Gerund", "Verb_Inf_Gerund", "Verb_Bare_Inf", "Verb_object_bare", "Restoration_alter", "Verb_part", "Get_part", "Complex_obj", "Verbal_idiom", "Prepositional_verb", "Dative", "Followed_by_a_clause", "that_clause", "if_whether_clause", "that_subj_clause", "it_conj_clause", "Participial_constr", "Infinitive_constr", "Gerund_phrase", "Nouns", "Countable_uncountable", "Prepositional_noun", "Possessive", "Noun_attribute", "Noun_inf", "Noun_number", "Prepositions", "Conjunctions", "Adjectives", "Comparative_adj", "Superlative_adj", "Prepositional_adjective", "Adj_as_collective", "Adverbs", "Comparative_adv", "Superlative_adv", "Prepositional_adv", "Numerals", "Pronouns", "Agreement_errors", "Word_order", "Standard", "Emphatic", "Cleft", "Interrogative", "Abs_comp_clause", "Exclamation", "Title_structure", "Note_structure", "Conditionals", "Attributes", "Relative_clause", "Defining", "Non_defining", "Coordinate", "Attr_participial", "Lack_par_constr", "Negation", "Comparative_constr", "Numerical", "Confusion_of_structures", "Vocabulary", "Word_choice", "lex_item_choice", "Often_confused", "lex_part_choice", "Absence_comp_colloc", "Redundant", "Derivation", "Formational_affixes", "Suffix", "Prefix", "Category_confusion", "Compound_word", "Discourse", "Ref_device", "Coherence", "Linking_device", "Inappropriate_register", "Absence_comp_sent", "Redundant_comp", "Absence_explanation", "delete"]
translate_dict = {e[1]: e[0] for e in zip(Conventional, Tags)}

Allowed_tags = Tags

General_dict = {i: {} for i in range(0,11)}
General_dict["Total"] = {}

for error in Allowed_tags:
  if error == "delete":
    data = All_Entries.loc[All_Entries['delete'] == True]
  else:
    data = All_Entries.loc[All_Entries['type'] == error]
  data = data.groupby('substr_words').size()
  General_dict['Total'][translate_dict[error]] = sum(data)
  data = dict(data)
  for i in range(0,11):
    if i in data:
      General_dict[i][translate_dict[error]] = data[i]
    else:
      General_dict[i][translate_dict[error]] = 0

Summary = pd.DataFrame(General_dict)
Summary['One-word %'] = Summary[1] / Summary['Total']
Summary['One-word %'] = Summary['One-word %'].apply(lambda x: round(x*100, 2))
with pd.option_context('display.max_rows', None, 'display.max_columns', None):
    display(Summary.sort_values('Total', ascending=0))
# Out:
#                                                  0      1     2     3    4  \
# Articles                                         1   8223  4106  1541  310
# Spelling                                         1  13326   678   236   26
# Choice of lexical item                           0   8934  1246   555  232
# Punctuation                                     27   4676  1946   858  554
# Deletion                                         4   5190   869   393  162
# Choice of tense                                  0   3786  1065   359   84
# Prepositions                                     0   4261   505   290  142
# Agreement                                        1   4034   170    70   15
# Redundant component in clause or sentence        0   2283   860   445  208
# Absence of a component in clause or sentence     1   1689   836   443  214
# Word choice                                      1   1705   701   343  223
# Noun number                                      4   2924   130    62   13
# Absence of necessary explanation or detail       0   1233   451   295  150
# Confusion of categories                          0   2035   199   112   29
# Standard word order                              0     12   322   262  206
# Referential device                               0   1147   194    81   43
# Numerals                                         0   1016   227    58   56
# Determiners                                      2    788   354   122   37
# Inappropriate register                           0    508   123   444   68
# Tense form                                       1    841   210    96   34
# Capitalisation                                   0   1027    58    63   12
# Words often confused                             0   1069    45    25    7
# Discourse                                        0    555   195   144   68
# Voice                                            0    463   340   124   25
# Absence of certain components of a collocation   1    672   141    70   25
# Choice of a part of lexical item                 0    271   240   233  102
# Redundant word(s)                                0    436   148    91   40
# Linking device                                   0    384   134    75   70
# Defining relative clause                         0    136   185    40   23
# Word order                                       2     75   148   106   73
# Pronouns                                         0    520    36    42    3
# Coherence                                        0    234    92    39   25
# Prepositional or phrasal verb                    0    237   181    49   23
# Conjunctions                                     0    432    49     8    4
# Modals                                           0    268   117    77   23
# Possessive form of a noun                        0    328    74    42   17
# Formational suffix                               0    437    23     3    0
# Comparative degree of adjectives                 0    219   133     9    9
# Confusion of structures                          0     67    95    67   40
# Incomplete sentence                              0    185    53    18   11
# Prepositional noun                               0     61   185    29    6
# Countable/uncountable                            0    220    35    20    7
# Transitive verb                                  0     65   141    31   25
# Infinitive construction                          0    147    86    15   12
# Non-defining relative clause                     7    132    27     2    7
# Word formation                                   0    194    24    11    2
# Parallel constructions                           0    144    54    12    8
# Superlative degree of adjectives                 0     97    81    38    6
# Verb pattern                                     0    112    51    18    5
# Derivational affixes                             0    183     6     0    0
# Comparative construction                         0     84    51    20    8
# Negation                                         0     55    50    40    7
# Adjectives                                       0    117    18    19    3
# Verb + Infinitive                                0     32    55    38   17
# Nouns                                            1    127     7    10    0
# Noun as an attribute                             0     63    27    25   13
# Formational prefix                               0     94    20     2    0
# Compound word                                    0     51    52     5    1
# Participial construction                         0     67    22    10    3
# Verbs                                            0     81    16     3    2
# Gerund phrase                                    0     44    38    14    2
# Adverbs                                          0     81    13     5    1
# Numerical comparison                             0     22    19    16   16
# Relative clause                                  0     57    11     2    3
# Note structure                                   0      8     4    44   23
# Tense                                            0     56    19     5    1
# Verb + Infinitive OR Gerund                      0     14    41    19    3
# Prepositional adjective                          0     28    36     5    0
# Verb + Bare Infinitive                           0      9    22    28    5
# Vocabulary                                       0     33    18     7    3
# Conditionals                                     0     17    16    12    6
# Attributive participial construction             0     14    18     4    2
# Interrogative word order                         0      5    17    11    6
# Verb + Gerund                                    0      8    26    17    2
# Coordinate relative clause                       0     43     2     0    2
# Verb + Object/Addressee + Bare Infinitive        0      8     2     2   15
# Grammar                                          0     19     4     2    3
# Quantifiers                                      0     15     7     4    2
# Noun + Infinitive                                0      2     5    13    5
# Adjective as a collective noun                   0     22     2     2    1
# Emphatic shift                                   0      2     6     4    2
# Attributes                                       0      6     5    11    3
# Dative verb with alternation                     0      9     5     4    2
# Intransitive verb                                0     17     5     1    0
# Verb + that/WH + Clause                          0     14     3     2    1
# Comparative degree of adverbs                    0     12     7     1    0
# Prepositional adverb                             0      6     3     0    0
# Verb + Participle                                0      3     4     1    1
# Cleft sentence                                   0      0     1     0    1
# Reflexive verb                                   0      6     0     0    0
# Verb + that + Subjunctive clause                 0      1     2     1    0
# Two verbal forms in the predicate                0      3     1     0    0
# Verb with as                                     0      0     1     0    1
# Verbal idiom                                     0      1     1     1    1
# Verb + if/whether + clause                       0      3     0     0    0
# Title structure                                  0      3     0     0    0
# Ambitransitive verb                              0      1     1     0    1
# Verb + it + Conj + Clause                        0      1     1     0    0
# Complex-object verb                              0      2     0     0    0
# Superlative degree of adverbs                    0      0     1     0    0
# Generic correction                               0      0     0     0    0
# Get + participle                                 0      0     0     0    0
# Verb followed by a clause                        0      0     0     0    0
# Exclamation                                      0      0     0     0    0
# Infinitive Restoration Alternation               0      0     0     0    0
#
#                                                   5    6    7   8   9  10  \
# Articles                                         89   25   12   2   2   0
# Spelling                                          3    7    0   0   0   1
# Choice of lexical item                           81   28   13  11   7   1
# Punctuation                                     250  156  119  77  67  44
# Deletion                                         97   54   34  20  15   5
# Choice of tense                                  14    4    6   0   2   0
# Prepositions                                     42    9    6   4   1   1
# Agreement                                         5    5    3   0   2   1
# Redundant component in clause or sentence       107   84   45  20  19   5
# Absence of a component in clause or sentence    106   60   35  27  30  23
# Word choice                                      97   48   33  12  16   8
# Noun number                                       2    0    0   1   0   0
# Absence of necessary explanation or detail       86   42   32  28  25  13
# Confusion of categories                          15    6    3   0   0   0
# Standard word order                             148  112  100  80  56  53
# Referential device                               12   10    4   1   2   3
# Numerals                                         12    4    3   1   1   0
# Determiners                                      11    2    0   1   1   1
# Inappropriate register                           37   16   17  17   9   8
# Tense form                                        6    3    2   0   0   0
# Capitalisation                                    0    1    0   1   0   0
# Words often confused                              3    1    1   0   0   0
# Discourse                                        33   24    8  16  10   4
# Voice                                             3    2    1   1   0   0
# Absence of certain components of a collocation    6    2    0   2   1   0
# Choice of a part of lexical item                 35   18    4   3   0   0
# Redundant word(s)                                22    3    3   4   1   0
# Linking device                                   27   13   13   7   4   3
# Defining relative clause                         42   50   38  41  31  23
# Word order                                       55   29   34  15  16   8
# Pronouns                                          1    1    0   0   0   0
# Coherence                                        18   17   11  12  15  11
# Prepositional or phrasal verb                     6    3    4   2   1   0
# Conjunctions                                      2    1    1   0   1   1
# Modals                                            9    2    0   0   0   0
# Possessive form of a noun                         6    0    0   0   0   0
# Formational suffix                                0    0    0   0   0   0
# Comparative degree of adjectives                  1    1    0   0   0   0
# Confusion of structures                          27   19    3  10  10   6
# Incomplete sentence                               5    3    5   5   0   7
# Prepositional noun                                5    2    1   1   0   0
# Countable/uncountable                             5    0    0   0   0   0
# Transitive verb                                  11    5    1   3   0   0
# Infinitive construction                           2    3    1   1   0   0
# Non-defining relative clause                     14    5   11  15   6   6
# Word formation                                    1    0    1   0   0   0
# Parallel constructions                            5    3    3   1   1   0
# Superlative degree of adjectives                  1    0    0   0   0   0
# Verb pattern                                      6    0    1   1   0   0
# Derivational affixes                              0    0    0   0   0   0
# Comparative construction                          6    2    1   4   3   0
# Negation                                          3    4    3   3   0   0
# Adjectives                                        0    0    0   0   0   0
# Verb + Infinitive                                 2    5    0   1   0   0
# Nouns                                             1    0    0   0   0   0
# Noun as an attribute                              3    2    1   0   0   0
# Formational prefix                                0    0    0   0   0   0
# Compound word                                     0    0    0   0   0   0
# Participial construction                          0    2    0   0   0   0
# Verbs                                             1    1    0   0   0   0
# Gerund phrase                                     2    1    1   1   0   0
# Adverbs                                           1    0    0   0   0   0
# Numerical comparison                             13    4    0   1   1   1
# Relative clause                                   1    5    3   0   1   0
# Note structure                                    1    1    0   0   0   1
# Tense                                             0    0    0   0   0   0
# Verb + Infinitive OR Gerund                       2    1    0   1   0   0
# Prepositional adjective                           0    0    0   0   0   0
# Verb + Bare Infinitive                            0    1    1   0   0   0
# Vocabulary                                        1    2    0   1   0   0
# Conditionals                                      1    2    0   1   0   1
# Attributive participial construction              4    3    3   1   5   0
# Interrogative word order                          5    2    2   3   0   0
# Verb + Gerund                                     3    0    0   0   0   0
# Coordinate relative clause                        0    1    1   0   0   0
# Verb + Object/Addressee + Bare Infinitive         5    1    0   0   1   0
# Grammar                                           1    0    0   0   0   0
# Quantifiers                                       1    0    0   1   0   0
# Noun + Infinitive                                 1    2    0   0   0   0
# Adjective as a collective noun                    0    0    0   0   0   0
# Emphatic shift                                    2    3    5   2   1   0
# Attributes                                        0    0    0   0   0   0
# Dative verb with alternation                      1    2    1   0   0   0
# Intransitive verb                                 0    0    0   0   0   0
# Verb + that/WH + Clause                           0    0    0   0   0   0
# Comparative degree of adverbs                     0    0    0   0   0   0
# Prepositional adverb                              0    0    0   0   0   0
# Verb + Participle                                 0    0    0   0   0   0
# Cleft sentence                                    0    2    0   3   0   0
# Reflexive verb                                    0    0    0   0   0   0
# Verb + that + Subjunctive clause                  0    0    0   0   0   0
# Two verbal forms in the predicate                 0    0    0   0   0   0
# Verb with as                                      0    1    1   0   0   0
# Verbal idiom                                      0    0    0   0   0   0
# Verb + if/whether + clause                        0    0    1   0   0   0
# Title structure                                   0    0    0   0   0   0
# Ambitransitive verb                               0    0    0   0   0   0
# Verb + it + Conj + Clause                         0    0    0   0   0   0
# Complex-object verb                               0    0    0   0   0   0
# Superlative degree of adverbs                     0    0    0   0   0   0
# Generic correction                                0    0    0   0   0   0
# Get + participle                                  0    0    0   0   0   0
# Verb followed by a clause                         0    0    0   0   0   0
# Exclamation                                       0    0    0   0   0   0
# Infinitive Restoration Alternation                0    0    0   0   0   0
#
#                                                 Total  One-word %
# Articles                                        14312       57.46
# Spelling                                        14278       93.33
# Choice of lexical item                          11114       80.39
# Punctuation                                      8950       52.25
# Deletion                                         6895       75.27
# Choice of tense                                  5323       71.13
# Prepositions                                     5261       80.99
# Agreement                                        4307       93.66
# Redundant component in clause or sentence        4134       55.22
# Absence of a component in clause or sentence     3511       48.11
# Word choice                                      3205       53.20
# Noun number                                      3137       93.21
# Absence of necessary explanation or detail       2448       50.37
# Confusion of categories                          2399       84.83
# Standard word order                              1535        0.78
# Referential device                               1504       76.26
# Numerals                                         1378       73.73
# Determiners                                      1319       59.74
# Inappropriate register                           1272       39.94
# Tense form                                       1195       70.38
# Capitalisation                                   1162       88.38
# Words often confused                             1151       92.88
# Discourse                                        1086       51.10
# Voice                                             963       48.08
# Absence of certain components of a collocation    923       72.81
# Choice of a part of lexical item                  908       29.85
# Redundant word(s)                                 751       58.06
# Linking device                                    747       51.41
# Defining relative clause                          660       20.61
# Word order                                        613       12.23
# Pronouns                                          603       86.24
# Coherence                                         510       45.88
# Prepositional or phrasal verb                     508       46.65
# Conjunctions                                      500       86.40
# Modals                                            497       53.92
# Possessive form of a noun                         467       70.24
# Formational suffix                                463       94.38
# Comparative degree of adjectives                  372       58.87
# Confusion of structures                           354       18.93
# Incomplete sentence                               306       60.46
# Prepositional noun                                290       21.03
# Countable/uncountable                             287       76.66
# Transitive verb                                   282       23.05
# Infinitive construction                           267       55.06
# Non-defining relative clause                      254       51.97
# Word formation                                    233       83.26
# Parallel constructions                            232       62.07
# Superlative degree of adjectives                  223       43.50
# Verb pattern                                      195       57.44
# Derivational affixes                              189       96.83
# Comparative construction                          181       46.41
# Negation                                          166       33.13
# Adjectives                                        157       74.52
# Verb + Infinitive                                 150       21.33
# Nouns                                             146       86.99
# Noun as an attribute                              134       47.01
# Formational prefix                                116       81.03
# Compound word                                     109       46.79
# Participial construction                          105       63.81
# Verbs                                             104       77.88
# Gerund phrase                                     104       42.31
# Adverbs                                           101       80.20
# Numerical comparison                               93       23.66
# Relative clause                                    84       67.86
# Note structure                                     82        9.76
# Tense                                              81       69.14
# Verb + Infinitive OR Gerund                        81       17.28
# Prepositional adjective                            69       40.58
# Verb + Bare Infinitive                             66       13.64
# Vocabulary                                         65       50.77
# Conditionals                                       59       28.81
# Attributive participial construction               57       24.56
# Interrogative word order                           57        8.77
# Verb + Gerund                                      56       14.29
# Coordinate relative clause                         52       82.69
# Verb + Object/Addressee + Bare Infinitive          35       22.86
# Grammar                                            31       61.29
# Quantifiers                                        30       50.00
# Noun + Infinitive                                  28        7.14
# Adjective as a collective noun                     27       81.48
# Emphatic shift                                     27        7.41
# Attributes                                         25       24.00
# Dative verb with alternation                       25       36.00
# Intransitive verb                                  23       73.91
# Verb + that/WH + Clause                            21       66.67
# Comparative degree of adverbs                      20       60.00
# Prepositional adverb                                9       66.67
# Verb + Participle                                   9       33.33
# Cleft sentence                                      7        0.00
# Reflexive verb                                      6      100.00
# Verb + that + Subjunctive clause                    4       25.00
# Two verbal forms in the predicate                   4       75.00
# Verb with as                                        4        0.00
# Verbal idiom                                        4       25.00
# Verb + if/whether + clause                          4       75.00
# Title structure                                     3      100.00
# Ambitransitive verb                                 3       33.33
# Verb + it + Conj + Clause                           2       50.00
# Complex-object verb                                 2      100.00
# Superlative degree of adverbs                       1        0.00
# Generic correction                                  0         NaN
# Get + participle                                    0         NaN
# Verb followed by a clause                           0         NaN
# Exclamation                                         0         NaN
# Infinitive Restoration Alternation                  0         NaN
